# %%
import numpy as np
import random
import nltk
import pickle
import json
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.optimizers import SGD
from nltk.stem import WordNetLemmatizer

# %%
lemmatizer = WordNetLemmatizer()
intents_file = open('intents.json').read()
intents = json.loads(intents_file)

# %%
words = []
classes = []
documents = []
ignore_letters = ['!', '?', ',', '.']
for intent in intents['intents']:
    for pattern in intent['patterns']:
        #tokenize each word
        word = nltk.word_tokenize(pattern)
        words.extend(word)
        #add documents in the corpus
        documents.append((word, intent['tag']))
        #add it to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])
print(documents)
# Out:
# [(['Hi', 'there'], 'greeting'), (['How', 'are', 'you'], 'greeting'), (['Is', 'anyone', 'there', '?'], 'greeting'), (['Hey'], 'greeting'), (['Hola'], 'greeting'), (['Hello'], 'greeting'), (['Good', 'day'], 'greeting'), (['Bye'], 'goodbye'), (['See', 'you', 'later'], 'goodbye'), (['Goodbye'], 'goodbye'), (['Nice', 'chatting', 'to', 'you', ',', 'bye'], 'goodbye'), (['Till', 'next', 'time'], 'goodbye'), (['Thanks'], 'thanks'), (['Thank', 'you'], 'thanks'), (['That', "'s", 'helpful'], 'thanks'), (['Awesome', ',', 'thanks'], 'thanks'), (['Thanks', 'for', 'helping', 'me'], 'thanks'), (['How', 'you', 'could', 'help', 'me', '?'], 'options'), (['What', 'you', 'can', 'do', '?'], 'options'), (['What', 'help', 'you', 'provide', '?'], 'options'), (['How', 'you', 'can', 'be', 'helpful', '?'], 'options'), (['What', 'support', 'is', 'offered'], 'options'), (['How', 'to', 'check', 'Adverse', 'drug', 'reaction', '?'], 'adverse_drug'), (['Open', 'adverse', 'drugs', 'module'], 'adverse_drug'), (['Give', 'me', 'a', 'list', 'of', 'drugs', 'causing', 'adverse', 'behavior'], 'adverse_drug'), (['List', 'all', 'drugs', 'suitable', 'for', 'patient', 'with', 'adverse', 'reaction'], 'adverse_drug'), (['Which', 'drugs', 'dont', 'have', 'adverse', 'reaction', '?'], 'adverse_drug'), (['Open', 'blood', 'pressure', 'module'], 'blood_pressure'), (['Task', 'related', 'to', 'blood', 'pressure'], 'blood_pressure'), (['Blood', 'pressure', 'data', 'entry'], 'blood_pressure'), (['I', 'want', 'to', 'log', 'blood', 'pressure', 'results'], 'blood_pressure'), (['Blood', 'pressure', 'data', 'management'], 'blood_pressure'), (['I', 'want', 'to', 'search', 'for', 'blood', 'pressure', 'result', 'history'], 'blood_pressure_search'), (['Blood', 'pressure', 'for', 'patient'], 'blood_pressure_search'), (['Load', 'patient', 'blood', 'pressure', 'result'], 'blood_pressure_search'), (['Show', 'blood', 'pressure', 'results', 'for', 'patient'], 'blood_pressure_search'), (['Find', 'blood', 'pressure', 'results', 'by', 'ID'], 'blood_pressure_search'), (['Find', 'me', 'a', 'pharmacy'], 'pharmacy_search'), (['Find', 'pharmacy'], 'pharmacy_search'), (['List', 'of', 'pharmacies', 'nearby'], 'pharmacy_search'), (['Locate', 'pharmacy'], 'pharmacy_search'), (['Search', 'pharmacy'], 'pharmacy_search'), (['Lookup', 'for', 'hospital'], 'hospital_search'), (['Searching', 'for', 'hospital', 'to', 'transfer', 'patient'], 'hospital_search'), (['I', 'want', 'to', 'search', 'hospital', 'data'], 'hospital_search'), (['Hospital', 'lookup', 'for', 'patient'], 'hospital_search'), (['Looking', 'up', 'hospital', 'details'], 'hospital_search')]

# %%
# lemmaztize and lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_letters]
words = sorted(list(set(words)))
# sort classes
classes = sorted(list(set(classes)))
# documents combination between patterns and intents
print(len(documents), "documents")
# classes = intents
print(len(classes), "classes")
# words = all words, vocabulary
print(len(word), "unique lemmatized words", words)
pickle.dump(words, open('words.pkl','wb'))
pickle.dump(classes, open('classes.pkl','wb'))
# Out:
# 47 documents
# 9 classes
# 4 unique lemmatized words ["'s", 'a', 'adverse', 'all', 'anyone', 'are', 'awesome', 'be', 'behavior', 'blood', 'by', 'bye', 'can', 'causing', 'chatting', 'check', 'could', 'data', 'day', 'detail', 'do', 'dont', 'drug', 'entry', 'find', 'for', 'give', 'good', 'goodbye', 'have', 'hello', 'help', 'helpful', 'helping', 'hey', 'hi', 'history', 'hola', 'hospital', 'how', 'i', 'id', 'is', 'later', 'list', 'load', 'locate', 'log', 'looking', 'lookup', 'management', 'me', 'module', 'nearby', 'next', 'nice', 'of', 'offered', 'open', 'patient', 'pharmacy', 'pressure', 'provide', 'reaction', 'related', 'result', 'search', 'searching', 'see', 'show', 'suitable', 'support', 'task', 'thank', 'thanks', 'that', 'there', 'till', 'time', 'to', 'transfer', 'up', 'want', 'what', 'which', 'with', 'you']

# %%
# create the training data
training = []
# create empty array for the output
output_empty = [0]*len(classes)
# training set, bag of words for every sentence
for doc in documents:
    # initializing bag of words
    bag = []
    # list of tokenized words for the pattern
    word_patterns = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    word_patterns = [lemmatizer.lemmatize(word.lower()) for word in word_patterns]
    # create the bag of words array with 1, if word is found in current pattern
    for word in words:
        bag.append(1) if word in word_patterns else bag.append(0)
        
    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    training.append([bag, output_row])
#shuffle the features and make numpy array
random.shuffle(training)
training = np.array(training)
# create training and testing lists. X - patterns, Y - intents
25
train_x = list(training[:,0])
26
train_y = list(training[:,1])
27
print("Training data is created")
# Out:
# Training data is created

# %%
#deep natural networds model
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation = 'softmax'))
# Compiling model. SGD with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr = 0.01, decay = 1e-6, momentum = 0.9, nesterov = True)
model.compile(loss = 'categorical_crossentropy', optimizer = sgd, metrics = ['accuracy'])
#Training and saving the model 
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size = 5, verbose = 1)
model.save('chatbot_model.h5', hist)
print("model is created")
# Out:
# Epoch 1/200
# 10/10 [==============================] - 0s 994us/step - loss: 2.2208 - accuracy: 0.1489
# Epoch 2/200
# 10/10 [==============================] - 0s 997us/step - loss: 2.1930 - accuracy: 0.2128
# Epoch 3/200
# 10/10 [==============================] - 0s 898us/step - loss: 2.0454 - accuracy: 0.2340
# Epoch 4/200
# 10/10 [==============================] - 0s 1ms/step - loss: 2.0285 - accuracy: 0.2553
# Epoch 5/200
# 10/10 [==============================] - 0s 997us/step - loss: 1.8702 - accuracy: 0.3191
# Epoch 6/200
# 10/10 [==============================] - 0s 999us/step - loss: 1.7617 - accuracy: 0.3191
# Epoch 7/200
# 10/10 [==============================] - 0s 997us/step - loss: 1.7468 - accuracy: 0.4681
# Epoch 8/200
# 10/10 [==============================] - 0s 897us/step - loss: 1.5735 - accuracy: 0.5319
# Epoch 9/200
# 10/10 [==============================] - 0s 897us/step - loss: 1.3987 - accuracy: 0.6170
# Epoch 10/200
# 10/10 [==============================] - 0s 898us/step - loss: 1.2651 - accuracy: 0.6383
# Epoch 11/200
# 10/10 [==============================] - 0s 698us/step - loss: 1.2262 - accuracy: 0.6383
# Epoch 12/200
# 10/10 [==============================] - 0s 1ms/step - loss: 1.1047 - accuracy: 0.6383
# Epoch 13/200
# 10/10 [==============================] - 0s 898us/step - loss: 0.9870 - accuracy: 0.7447
# Epoch 14/200
# 10/10 [==============================] - 0s 898us/step - loss: 0.8368 - accuracy: 0.8511
# Epoch 15/200
# 10/10 [==============================] - 0s 698us/step - loss: 0.7654 - accuracy: 0.7660
# Epoch 16/200
# 10/10 [==============================] - 0s 898us/step - loss: 0.7974 - accuracy: 0.7447
# Epoch 17/200
# 10/10 [==============================] - 0s 798us/step - loss: 0.7099 - accuracy: 0.8085
# Epoch 18/200
# 10/10 [==============================] - 0s 798us/step - loss: 0.5718 - accuracy: 0.8511
# Epoch 19/200
# 10/10 [==============================] - 0s 898us/step - loss: 0.5793 - accuracy: 0.8298
# Epoch 20/200
# 10/10 [==============================] - 0s 898us/step - loss: 0.5582 - accuracy: 0.8723
# Epoch 21/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.5036 - accuracy: 0.9149
# Epoch 22/200
# 10/10 [==============================] - 0s 698us/step - loss: 0.5111 - accuracy: 0.8723
# Epoch 23/200
# 10/10 [==============================] - 0s 798us/step - loss: 0.4507 - accuracy: 0.8298
# Epoch 24/200
# 10/10 [==============================] - 0s 698us/step - loss: 0.3053 - accuracy: 0.9362
# Epoch 25/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.3276 - accuracy: 0.9362
# Epoch 26/200
# 10/10 [==============================] - 0s 798us/step - loss: 0.2577 - accuracy: 0.9362
# Epoch 27/200
# 10/10 [==============================] - 0s 698us/step - loss: 0.3147 - accuracy: 0.9149
# Epoch 28/200
# 10/10 [==============================] - 0s 798us/step - loss: 0.2943 - accuracy: 0.8936
# Epoch 29/200
# 10/10 [==============================] - 0s 698us/step - loss: 0.2299 - accuracy: 0.9574
# Epoch 30/200
# 10/10 [==============================] - 0s 698us/step - loss: 0.3339 - accuracy: 0.9149
# Epoch 31/200
# 10/10 [==============================] - 0s 898us/step - loss: 0.3221 - accuracy: 0.9149
# Epoch 32/200
# 10/10 [==============================] - 0s 698us/step - loss: 0.2855 - accuracy: 0.9362
# Epoch 33/200
# 10/10 [==============================] - 0s 698us/step - loss: 0.3439 - accuracy: 0.8511
# Epoch 34/200
# 10/10 [==============================] - 0s 898us/step - loss: 0.2166 - accuracy: 0.9149
# Epoch 35/200
# 10/10 [==============================] - 0s 899us/step - loss: 0.2218 - accuracy: 0.9362
# Epoch 36/200
# 10/10 [==============================] - 0s 698us/step - loss: 0.2847 - accuracy: 0.9149
# Epoch 37/200
# 10/10 [==============================] - 0s 798us/step - loss: 0.2826 - accuracy: 0.9149
# Epoch 38/200
# 10/10 [==============================] - 0s 698us/step - loss: 0.2385 - accuracy: 0.8936
# Epoch 39/200
# 10/10 [==============================] - 0s 898us/step - loss: 0.1481 - accuracy: 0.9787
# Epoch 40/200
# 10/10 [==============================] - 0s 698us/step - loss: 0.1064 - accuracy: 0.9574
# Epoch 41/200
# 10/10 [==============================] - 0s 698us/step - loss: 0.1807 - accuracy: 0.9362
# Epoch 42/200
# 10/10 [==============================] - 0s 897us/step - loss: 0.1548 - accuracy: 0.9787
# Epoch 43/200
# 10/10 [==============================] - 0s 798us/step - loss: 0.1592 - accuracy: 0.9787
# Epoch 44/200
# 10/10 [==============================] - 0s 598us/step - loss: 0.1500 - accuracy: 0.9787
# Epoch 45/200
# 10/10 [==============================] - 0s 899us/step - loss: 0.2397 - accuracy: 0.9149
# Epoch 46/200
# 10/10 [==============================] - 0s 698us/step - loss: 0.1107 - accuracy: 0.9574
# Epoch 47/200
# 10/10 [==============================] - 0s 798us/step - loss: 0.1867 - accuracy: 0.9574
# Epoch 48/200
# 10/10 [==============================] - 0s 897us/step - loss: 0.1653 - accuracy: 0.9574
# Epoch 49/200
# 10/10 [==============================] - 0s 598us/step - loss: 0.1195 - accuracy: 0.9787
# Epoch 50/200
# 10/10 [==============================] - 0s 798us/step - loss: 0.0821 - accuracy: 0.9787
# Epoch 51/200
# 10/10 [==============================] - 0s 698us/step - loss: 0.0815 - accuracy: 0.9787
# Epoch 52/200
# 10/10 [==============================] - 0s 598us/step - loss: 0.0962 - accuracy: 0.9787
# Epoch 53/200
# 10/10 [==============================] - 0s 998us/step - loss: 0.0968 - accuracy: 0.9787
# Epoch 54/200
# 10/10 [==============================] - 0s 898us/step - loss: 0.1314 - accuracy: 0.9362
# Epoch 55/200
# 10/10 [==============================] - 0s 698us/step - loss: 0.0574 - accuracy: 1.0000
# Epoch 56/200
# 10/10 [==============================] - 0s 798us/step - loss: 0.0428 - accuracy: 1.0000
# Epoch 57/200
# 10/10 [==============================] - 0s 798us/step - loss: 0.0941 - accuracy: 1.0000
# Epoch 58/200
# 10/10 [==============================] - 0s 698us/step - loss: 0.1381 - accuracy: 0.9574
# Epoch 59/200
# 10/10 [==============================] - 0s 698us/step - loss: 0.0545 - accuracy: 1.0000
# Epoch 60/200
# 10/10 [==============================] - 0s 698us/step - loss: 0.0922 - accuracy: 0.9787
# Epoch 61/200
# 10/10 [==============================] - 0s 698us/step - loss: 0.1384 - accuracy: 0.9574
# Epoch 62/200
# 10/10 [==============================] - 0s 698us/step - loss: 0.0956 - accuracy: 0.9787
# Epoch 63/200
# 10/10 [==============================] - 0s 998us/step - loss: 0.0375 - accuracy: 1.0000
# Epoch 64/200
# 10/10 [==============================] - 0s 598us/step - loss: 0.0729 - accuracy: 0.9787
# Epoch 65/200
# 10/10 [==============================] - 0s 599us/step - loss: 0.1055 - accuracy: 0.9574
# Epoch 66/200
# 10/10 [==============================] - 0s 698us/step - loss: 0.0330 - accuracy: 1.0000
# Epoch 67/200
# 10/10 [==============================] - 0s 698us/step - loss: 0.0902 - accuracy: 0.9787
# Epoch 68/200
# 10/10 [==============================] - 0s 698us/step - loss: 0.0758 - accuracy: 1.0000
# Epoch 69/200
# 10/10 [==============================] - 0s 598us/step - loss: 0.0800 - accuracy: 0.9787
# Epoch 70/200
# 10/10 [==============================] - 0s 698us/step - loss: 0.1399 - accuracy: 0.9362
# Epoch 71/200
# 10/10 [==============================] - 0s 698us/step - loss: 0.0488 - accuracy: 1.0000
# Epoch 72/200
# 10/10 [==============================] - 0s 499us/step - loss: 0.0782 - accuracy: 1.0000
# Epoch 73/200
# 10/10 [==============================] - 0s 798us/step - loss: 0.0677 - accuracy: 0.9787
# Epoch 74/200
# 10/10 [==============================] - 0s 598us/step - loss: 0.1055 - accuracy: 0.9787
# Epoch 75/200
# 10/10 [==============================] - 0s 698us/step - loss: 0.0483 - accuracy: 1.0000
# Epoch 76/200
# 10/10 [==============================] - 0s 698us/step - loss: 0.0447 - accuracy: 0.9787
# Epoch 77/200
# 10/10 [==============================] - 0s 698us/step - loss: 0.0435 - accuracy: 0.9787
# Epoch 78/200
# 10/10 [==============================] - 0s 798us/step - loss: 0.0309 - accuracy: 1.0000
# Epoch 79/200
# 10/10 [==============================] - 0s 698us/step - loss: 0.1179 - accuracy: 0.9787
# Epoch 80/200
# 10/10 [==============================] - 0s 798us/step - loss: 0.1446 - accuracy: 0.9574
# Epoch 81/200
# 10/10 [==============================] - 0s 698us/step - loss: 0.0582 - accuracy: 0.9787
# Epoch 82/200
# 10/10 [==============================] - 0s 798us/step - loss: 0.0208 - accuracy: 1.0000
# Epoch 83/200
# 10/10 [==============================] - 0s 698us/step - loss: 0.1122 - accuracy: 0.9787
# Epoch 84/200
# 10/10 [==============================] - 0s 598us/step - loss: 0.0671 - accuracy: 0.9787
# Epoch 85/200
# 10/10 [==============================] - 0s 798us/step - loss: 0.0522 - accuracy: 1.0000
# Epoch 86/200
# 10/10 [==============================] - 0s 698us/step - loss: 0.0615 - accuracy: 1.0000
# Epoch 87/200
# 10/10 [==============================] - 0s 698us/step - loss: 0.0633 - accuracy: 0.9787
# Epoch 88/200
# 10/10 [==============================] - 0s 797us/step - loss: 0.0317 - accuracy: 1.0000
# Epoch 89/200
# 10/10 [==============================] - 0s 698us/step - loss: 0.0673 - accuracy: 0.9787
# Epoch 90/200
# 10/10 [==============================] - 0s 598us/step - loss: 0.0942 - accuracy: 0.9787
# Epoch 91/200
# 10/10 [==============================] - 0s 698us/step - loss: 0.0738 - accuracy: 1.0000
# Epoch 92/200
# 10/10 [==============================] - 0s 598us/step - loss: 0.0767 - accuracy: 0.9574
# Epoch 93/200
# 10/10 [==============================] - 0s 997us/step - loss: 0.0715 - accuracy: 0.9787
# Epoch 94/200
# 10/10 [==============================] - 0s 698us/step - loss: 0.0451 - accuracy: 1.0000
# Epoch 95/200
# 10/10 [==============================] - 0s 680us/step - loss: 0.0244 - accuracy: 1.0000
# Epoch 96/200
# 10/10 [==============================] - 0s 798us/step - loss: 0.0170 - accuracy: 1.0000
# Epoch 97/200
# 10/10 [==============================] - 0s 700us/step - loss: 0.0151 - accuracy: 1.0000
# Epoch 98/200
# 10/10 [==============================] - 0s 794us/step - loss: 0.0368 - accuracy: 0.9787
# Epoch 99/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0237 - accuracy: 1.0000
# Epoch 100/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0392 - accuracy: 0.9787
# Epoch 101/200
# 10/10 [==============================] - 0s 997us/step - loss: 0.0844 - accuracy: 0.9574
# Epoch 102/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0656 - accuracy: 0.9787
# Epoch 103/200
# 10/10 [==============================] - 0s 798us/step - loss: 0.0422 - accuracy: 0.9787
# Epoch 104/200
# 10/10 [==============================] - 0s 598us/step - loss: 0.0322 - accuracy: 1.0000
# Epoch 105/200
# 10/10 [==============================] - 0s 701us/step - loss: 0.0490 - accuracy: 1.0000
# Epoch 106/200
# 10/10 [==============================] - 0s 795us/step - loss: 0.0295 - accuracy: 1.0000
# Epoch 107/200
# 10/10 [==============================] - 0s 698us/step - loss: 0.0108 - accuracy: 1.0000
# Epoch 108/200
# 10/10 [==============================] - 0s 798us/step - loss: 0.0499 - accuracy: 0.9787
# Epoch 109/200
# 10/10 [==============================] - 0s 598us/step - loss: 0.0250 - accuracy: 1.0000
# Epoch 110/200
# 10/10 [==============================] - 0s 598us/step - loss: 0.0387 - accuracy: 0.9787
# Epoch 111/200
# 10/10 [==============================] - 0s 598us/step - loss: 0.0259 - accuracy: 1.0000
# Epoch 112/200
# 10/10 [==============================] - 0s 598us/step - loss: 0.0124 - accuracy: 1.0000
# Epoch 113/200
# 10/10 [==============================] - 0s 598us/step - loss: 0.0239 - accuracy: 1.0000
# Epoch 114/200
# 10/10 [==============================] - 0s 698us/step - loss: 0.0080 - accuracy: 1.0000
# Epoch 115/200
# 10/10 [==============================] - 0s 798us/step - loss: 0.0476 - accuracy: 1.0000
# Epoch 116/200
# 10/10 [==============================] - 0s 600us/step - loss: 0.0265 - accuracy: 1.0000
# Epoch 117/200
# 10/10 [==============================] - 0s 800us/step - loss: 0.0301 - accuracy: 0.9787
# Epoch 118/200
# 10/10 [==============================] - 0s 595us/step - loss: 0.0541 - accuracy: 0.9787
# Epoch 119/200
# 10/10 [==============================] - 0s 701us/step - loss: 0.0179 - accuracy: 1.0000
# Epoch 120/200
# 10/10 [==============================] - 0s 599us/step - loss: 0.0639 - accuracy: 0.9787
# Epoch 121/200
# 10/10 [==============================] - 0s 598us/step - loss: 0.0319 - accuracy: 1.0000
# Epoch 122/200
# 10/10 [==============================] - 0s 598us/step - loss: 0.0208 - accuracy: 1.0000
# Epoch 123/200
# 10/10 [==============================] - 0s 701us/step - loss: 0.0499 - accuracy: 1.0000
# Epoch 124/200
# 10/10 [==============================] - 0s 698us/step - loss: 0.0295 - accuracy: 1.0000
# Epoch 125/200
# 10/10 [==============================] - 0s 596us/step - loss: 0.0240 - accuracy: 1.0000
# Epoch 126/200
# 10/10 [==============================] - 0s 701us/step - loss: 0.0117 - accuracy: 1.0000
# Epoch 127/200
# 10/10 [==============================] - 0s 596us/step - loss: 0.0193 - accuracy: 1.0000
# Epoch 128/200
# 10/10 [==============================] - 0s 698us/step - loss: 0.0432 - accuracy: 0.9787
# Epoch 129/200
# 10/10 [==============================] - 0s 701us/step - loss: 0.0138 - accuracy: 1.0000
# Epoch 130/200
# 10/10 [==============================] - 0s 601us/step - loss: 0.0157 - accuracy: 1.0000
# Epoch 131/200
# 10/10 [==============================] - 0s 700us/step - loss: 0.0255 - accuracy: 1.0000
# Epoch 132/200
# 10/10 [==============================] - 0s 698us/step - loss: 0.0752 - accuracy: 0.9787
# Epoch 133/200
# 10/10 [==============================] - 0s 899us/step - loss: 0.0127 - accuracy: 1.0000
# Epoch 134/200
# 10/10 [==============================] - 0s 596us/step - loss: 0.0209 - accuracy: 1.0000
# Epoch 135/200
# 10/10 [==============================] - 0s 695us/step - loss: 0.0366 - accuracy: 1.0000
# Epoch 136/200
# 10/10 [==============================] - 0s 698us/step - loss: 0.0324 - accuracy: 1.0000
# Epoch 137/200
# 10/10 [==============================] - 0s 598us/step - loss: 0.0163 - accuracy: 1.0000
# Epoch 138/200
# 10/10 [==============================] - 0s 698us/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 139/200
# 10/10 [==============================] - 0s 597us/step - loss: 0.0537 - accuracy: 0.9787
# Epoch 140/200
# 10/10 [==============================] - 0s 798us/step - loss: 0.0399 - accuracy: 0.9787
# Epoch 141/200
# 10/10 [==============================] - 0s 499us/step - loss: 0.0056 - accuracy: 1.0000
# Epoch 142/200
# 10/10 [==============================] - 0s 698us/step - loss: 0.0567 - accuracy: 1.0000
# Epoch 143/200
# 10/10 [==============================] - 0s 698us/step - loss: 0.0180 - accuracy: 1.0000
# Epoch 144/200
# 10/10 [==============================] - 0s 598us/step - loss: 0.0417 - accuracy: 0.9787
# Epoch 145/200
# 10/10 [==============================] - 0s 997us/step - loss: 0.0081 - accuracy: 1.0000
# Epoch 146/200
# 10/10 [==============================] - 0s 598us/step - loss: 0.0163 - accuracy: 1.0000
# Epoch 147/200
# 10/10 [==============================] - 0s 700us/step - loss: 0.0272 - accuracy: 1.0000
# Epoch 148/200
# 10/10 [==============================] - 0s 695us/step - loss: 0.0229 - accuracy: 1.0000
# Epoch 149/200
# 10/10 [==============================] - 0s 598us/step - loss: 0.0097 - accuracy: 1.0000
# Epoch 150/200
# 10/10 [==============================] - 0s 698us/step - loss: 0.0218 - accuracy: 1.0000
# Epoch 151/200
# 10/10 [==============================] - 0s 698us/step - loss: 0.0119 - accuracy: 1.0000
# Epoch 152/200
# 10/10 [==============================] - 0s 802us/step - loss: 0.0109 - accuracy: 1.0000
# Epoch 153/200
# 10/10 [==============================] - 0s 698us/step - loss: 0.0284 - accuracy: 1.0000
# Epoch 154/200
# 10/10 [==============================] - 0s 698us/step - loss: 0.0153 - accuracy: 1.0000
# Epoch 155/200
# 10/10 [==============================] - 0s 794us/step - loss: 0.0256 - accuracy: 1.0000
# Epoch 156/200
# 10/10 [==============================] - 0s 698us/step - loss: 0.0126 - accuracy: 1.0000
# Epoch 157/200
# 10/10 [==============================] - 0s 695us/step - loss: 0.0311 - accuracy: 0.9787
# Epoch 158/200
# 10/10 [==============================] - 0s 598us/step - loss: 0.0329 - accuracy: 1.0000
# Epoch 159/200
# 10/10 [==============================] - 0s 698us/step - loss: 0.0316 - accuracy: 1.0000
# Epoch 160/200
# 10/10 [==============================] - 0s 598us/step - loss: 0.0358 - accuracy: 0.9787
# Epoch 161/200
# 10/10 [==============================] - 0s 701us/step - loss: 0.0251 - accuracy: 1.0000
# Epoch 162/200
# 10/10 [==============================] - 0s 698us/step - loss: 0.0076 - accuracy: 1.0000
# Epoch 163/200
# 10/10 [==============================] - 0s 698us/step - loss: 0.0246 - accuracy: 1.0000
# Epoch 164/200
# 10/10 [==============================] - 0s 800us/step - loss: 0.1141 - accuracy: 0.9787
# Epoch 165/200
# 10/10 [==============================] - ETA: 0s - loss: 0.0236 - accuracy: 1.00 - 0s 595us/step - loss: 0.0162 - accuracy: 1.0000
# Epoch 166/200
# 10/10 [==============================] - 0s 798us/step - loss: 0.1424 - accuracy: 0.9574
# Epoch 167/200
# 10/10 [==============================] - 0s 698us/step - loss: 0.0285 - accuracy: 1.0000
# Epoch 168/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0245 - accuracy: 0.9787
# Epoch 169/200
# 10/10 [==============================] - 0s 701us/step - loss: 0.0599 - accuracy: 0.9787
# Epoch 170/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0305 - accuracy: 1.0000
# Epoch 171/200
# 10/10 [==============================] - 0s 695us/step - loss: 0.0128 - accuracy: 1.0000
# Epoch 172/200
# 10/10 [==============================] - 0s 598us/step - loss: 0.0929 - accuracy: 0.9787
# Epoch 173/200
# 10/10 [==============================] - 0s 798us/step - loss: 0.0387 - accuracy: 1.0000
# Epoch 174/200
# 10/10 [==============================] - 0s 698us/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 175/200
# 10/10 [==============================] - 0s 898us/step - loss: 0.0154 - accuracy: 1.0000
# Epoch 176/200
# 10/10 [==============================] - 0s 598us/step - loss: 0.0662 - accuracy: 0.9574
# Epoch 177/200
# 10/10 [==============================] - 0s 797us/step - loss: 0.0596 - accuracy: 0.9787
# Epoch 178/200
# 10/10 [==============================] - 0s 798us/step - loss: 0.0144 - accuracy: 1.0000
# Epoch 179/200
# 10/10 [==============================] - 0s 598us/step - loss: 0.0357 - accuracy: 0.9787
# Epoch 180/200
# 10/10 [==============================] - 0s 798us/step - loss: 0.0394 - accuracy: 1.0000
# Epoch 181/200
# 10/10 [==============================] - 0s 598us/step - loss: 0.0359 - accuracy: 1.0000
# Epoch 182/200
# 10/10 [==============================] - 0s 698us/step - loss: 0.0109 - accuracy: 1.0000
# Epoch 183/200
# 10/10 [==============================] - 0s 698us/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 184/200
# 10/10 [==============================] - 0s 698us/step - loss: 0.0387 - accuracy: 0.9787
# Epoch 185/200
# 10/10 [==============================] - 0s 695us/step - loss: 0.0182 - accuracy: 1.0000
# Epoch 186/200
# 10/10 [==============================] - 0s 699us/step - loss: 0.0065 - accuracy: 1.0000
# Epoch 187/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0123 - accuracy: 1.0000
# Epoch 188/200
# 10/10 [==============================] - 0s 798us/step - loss: 0.0258 - accuracy: 1.0000
# Epoch 189/200
# 10/10 [==============================] - 0s 698us/step - loss: 0.0208 - accuracy: 1.0000
# Epoch 190/200
# 10/10 [==============================] - 0s 898us/step - loss: 0.0249 - accuracy: 0.9787
# Epoch 191/200
# 10/10 [==============================] - 0s 698us/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 192/200
# 10/10 [==============================] - 0s 598us/step - loss: 0.1119 - accuracy: 0.9574
# Epoch 193/200
# 10/10 [==============================] - 0s 895us/step - loss: 0.0318 - accuracy: 1.0000
# Epoch 194/200
# 10/10 [==============================] - 0s 598us/step - loss: 0.0178 - accuracy: 1.0000
# Epoch 195/200
# 10/10 [==============================] - 0s 796us/step - loss: 0.0076 - accuracy: 1.0000
# Epoch 196/200
# 10/10 [==============================] - 0s 798us/step - loss: 0.0288 - accuracy: 1.0000
# Epoch 197/200
# 10/10 [==============================] - 0s 798us/step - loss: 0.0717 - accuracy: 0.9574
# Epoch 198/200
# 10/10 [==============================] - 0s 698us/step - loss: 0.0428 - accuracy: 0.9787
# Epoch 199/200
# 10/10 [==============================] - 0s 898us/step - loss: 0.0226 - accuracy: 1.0000
# Epoch 200/200
# 10/10 [==============================] - 0s 898us/step - loss: 0.0034 - accuracy: 1.0000
# model is created
